# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import re
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,classification_report
nltk.download('stopwords')
from pylab import rcParams
nltk.download('wordnet')
nltk.download('punkt')
import string as st
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data = pd.read_csv('/content/train - train.csv')
df_test = pd.read_csv('/content/test - test.csv')

# %%
def preprocess(data):
  def lemmatize(text):
    word_net = WordNetLemmatizer()
    return [word_net.lemmatize(word) for word in text]
  def remove_stopwords(text):
    return [word for word in text if word not in nltk.corpus.stopwords.words('english')]
  def remove_small_words(text):
    return [x for x in text if len(x) > 3 ]
  def tokenize(text):
    text = re.split('\s+' ,text)
    return [x.lower() for x in text]
  def remove_punct(text):
    return ("".join([ch for ch in text if ch not in st.punctuation]))
  data['text'] = data['text'].apply(lambda x: remove_punct(x))
  data['text'] = data['text'].apply(lambda x : tokenize(x))
  data['text'] = data['text'].apply(lambda x : remove_small_words(x))
  data['text'] = data['text'].apply(lambda x : lemmatize(x))
  return data

# %%
preprocess(data)
# Out:
#                                                    text  ... label
# 0               [check, whether, cancelled, completely]  ...     1
# 1     [cannot, rely, both, milk, delivery, grocery, ...  ...     0
# 2                 [notification, however, really, fine]  ...     0
# 3     [love, this, would, love, even, more, gantt, c...  ...     1
# 4                              [doe, load, clip, scene]  ...     0
# ...                                                 ...  ...   ...
# 3995  [every, time, edit, page, create, link, tool, ...  ...     0
# 3996  [unable, load, money, using, wallet, phonepeol...  ...     0
# 3997  [doing, first, time, ever, able, understand, u...  ...     0
# 3998  [delivery, delayed, cancelled, every, time, or...  ...     0
# 3999                [your, customer, service, terrible]  ...     0
#
# [4000 rows x 3 columns]
